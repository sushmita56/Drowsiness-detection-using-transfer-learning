# %%
from imutils import paths
train_data = r'D:\Deep Learning\Drowsiness Detection\dataset_new\train'
test_data = r'D:\Deep Learning\Drowsiness Detection\dataset_new\test' 
train_data_paths = list(paths.list_images(train_data))
test_data_paths = list(paths.list_images(test_data))
print(len(train_data_paths), len(test_data_paths))
# Out:
# 2467 426

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
def plot_images(directory, top=10):
    all_item_dirs = os.listdir(directory)
    item_files = [os.path.join(directory, file) for file in all_item_dirs][:5]

    plt.figure(figsize=(20, 20))
    for i, img_path in enumerate(item_files):
        plt.subplot(8, 8, i+1)
    
        img = plt.imread(img_path) 
        plt.tight_layout()       # Adjust the padding between and around subplots  
        plt.imshow(img, cmap='hot')

# %%
data_path = r'D:\Deep Learning\Drowsiness Detection\dataset_new\train'
directories = ['/Closed', '/Open', '/no_yawn', '/yawn']

# %%
for j in directories:
    plot_images(data_path + j)

# %%
img = cv2.imread(r'D:\Deep Learning\Drowsiness Detection\dataset_new\train\1.jpg')
# img = cv2.imread('D:\Deep Learning\FaceMaskDetector\images\image-4.jpeg')

# %%
type(img)
# Out:
# NoneType

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
batch_size = 100
train_datagen = ImageDataGenerator(rotation_range = 20, zoom_range = 5, width_shift_range=0.2, height_shift_range=0.2,
                                   shear_range=0.15, horizontal_flip=True, vertical_flip=True, fill_mode='nearest')
test_datagen = ImageDataGenerator(rotation_range = 20, zoom_range = 5, width_shift_range=0.2, height_shift_range=0.2,
                                 shear_range=0.15, horizontal_flip=True, vertical_flip=True, fill_mode="nearest")

# %%
train_data_path = r'D:\Deep Learning\Drowsiness Detection\dataset_new\train'
test_data_path = r'D:\Deep Learning\Drowsiness Detection\dataset_new\test'

# %%
train_set = train_datagen.flow_from_directory(train_data_path, target_size = (256,256),
                                              batch_size = batch_size, 
                                              color_mode = 'grayscale',
                                              class_mode = 'categorical')
test_set = test_datagen.flow_from_directory(test_data_path, target_size = (256,256),
                                           batch_size = batch_size,
                                           color_mode = 'grayscale',
                                           class_mode = 'categorical')
# Out:
# Found 2467 images belonging to 4 classes.
# Found 426 images belonging to 4 classes.

# %%
train_set

# %%
batch_size = 40
img_height = 256
img_width = 256
## loading training data
training_ds = tf.keras.preprocessing.image_dataset_from_directory(
    r'D:\Deep Learning\Drowsiness Detection\dataset_new\train',
    #validation_split=0.2,
    #subset= "training",
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size

)

## loading testing data
testing_ds = tf.keras.preprocessing.image_dataset_from_directory(
r'D:\Deep Learning\Drowsiness Detection\dataset_new\test',
    #validation_split=0.2,
    #subset= "validation",
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size

)
# Out:
# Found 2467 files belonging to 4 classes.
# Found 426 files belonging to 4 classes.

# %%
class_names = training_ds.class_names

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_ds = training_ds.cache().prefetch(buffer_size=AUTOTUNE)
testing_ds = testing_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model = Sequential(
[
    layers.experimental.preprocessing.Rescaling(1./255)
])

# %%
classes = 4

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization, Flatten, InputLayer

# %%
# model = Sequential()

# model.add(InputLayer(input_shape=(128,128,3)))
# model.add(Conv2D(32, (3,3), padding='same', strides=(1,1), activation='relu'))
# model.add(MaxPooling2D((2,2), strides=(2,2)))
# model.add(Conv2D(32, (3,3), padding='same', strides=(1,1), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2,2), strides=(2,2)))
# model.add(Conv2D(64, (3,3), padding='same', strides=(1,1), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2,2), strides=(2,2)))
# model.add(Conv2D(64, (3,3), padding='same', strides=(1,1), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D((2,2), strides=(2,2)))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dense(4, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
num_epochs = 10
training_steps=train_set.n//train_set.batch_size
validation_steps =test_set.n//test_set.batch_size

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_path="yawn_detection1.h5"

checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, 
                              save_best_only=True, mode='max')

callbacks_list = [checkpoint]

# %%
history = model.fit_generator(train_set, epochs=10, steps_per_epoch=training_steps,validation_data=test_set)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9452/446351825.py in <module>
# ----> 1 history = model.fit_generator(train_set, epochs=10, steps_per_epoch=training_steps,validation_data=test_set)
#
# ~\anaconda3\envs\tfEnv\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1970                   'will be removed in a future version. '
#    1971                   'Please use `Model.fit`, which supports generators.')
# -> 1972     return self.fit(
#    1973         generator,
#    1974         steps_per_epoch=steps_per_epoch,
#
# ...
